# %% [markdown]
# # Hunting for solar-related cyclicities over the Holocene
#
# ## Authors
#
# Deborah Khider [![ORCID](https://img.shields.io/badge/ORCID-0000--0001--7501--8430-A6CE39?logo=orcid)](https://orcid.org/0000-0001-7501-8430)
#
# ## Preamble
#
# Centennial to millennial quasi-periodic oscillations appear in all manner of well-dated Holocene paleoclimate records. Though the origin of this variability is debated, the similarity between the periods recovered from the spectral analysis of Holocene paleoclimate records and corresponding reconstructions of total solar irradiance (TSI) has led to the hypothesis that TSI variations drive Holocene climate cycles (the "solar hypothesis"). In this notebook, we demonstrate the use of the [`Pyleoclim` software package](https://pyleoclim-util.readthedocs.io/en/latest/) to estimate the spectra from Holocene temperature records and estimate whether they exhibit significant periodicities in the 800-3000 year band.
#
# Technical skills involved:
#
# - Loading data in the [LiPD](https://lipd.net) format using the [LiPDGraph](https://linkedearth.graphdb.mint.isi.edu).
# - Applying and interpreting spectral analysis in with [`Pyleoclim`](https://pyleoclim-util.readthedocs.io/en/latest/)
# - Estimating significant periodicities.
#
#
# ### Data
#
# The data is from the Temperature 12k Database by [Kaufman et al. (2020)](10.1038/s41597-020-0530-7), stored in the Linked PaleoData ([LiPD](https://lipd.net)) format on the [LiPDGraph](https://linkedearth.graphdb.mint.isi.edu).
#
# ### Reading time
# 15 min
#
# ### Keywords
# Pyleoclim; LiPD; SPARQL; Holocene; Spectral Analysis.

# %% [markdown]
# ## Data Retrieval
#
# While the [Holocene scaling notebook](../notebooks/02b-spectral_analysis_temp12k.ipynb) used one approach to retrieve the relevant records, this one illustrates the use of a [SPARQL](http://linked.earth/pylipdTutorials/graph.html#what-is-sparql) on the [LiPDGraph](https://linkedearth.graphdb.mint.isi.edu/). For more details, see [this tutorial](http://linked.earth/pylipdTutorials/notebooks/L2_using_graphdb.html).
#
# We need to return the following information for all the datasets included in the `Temp12k` compilation with the variable name `temperature`:
#
# - `dataSetName`: The name of the dataset
# - `archiveType`: The type of archive on which the measurements were made
# - `Latitude`, `Longitude`, and `Elevation`: the geographical coordinates for the site
# - `paleoData_variableName`: The name of the paleo variable as originally reported by the investigator
# - `paleoData_standardName`: The standard name for the paleo variable (here, `temperature`)
# - `paleoData_values`: The values for the paleo variable
# - `paleoData_units`: The units associated with the paleo variable
# - `paleoData_proxy`: The proxy used to infer paleoenvironmental conditions
# - `paleoData_proxyGeneral`: Generalized grouping for proxy
# - `TSiD`: The unique ID for the timeseries
# - `time_variableName`: The name for the time variable. Since we are dealing with the common era, should be all “year”.
# - `timevar_standardName`: The standard name for the time variable. Since we are dealing with the common era, should be all “year”. So let’s use this as a filter.
# - `time_values`: The values for the time axis
# - `time_units`: the units for the time axis.
#
# The full process to query the database and ensure that the results make sense is described in the didactic notebook [Querying the LiPDGraph](query_lipd_graph.ipynb). The resulting correct query is pasted below:

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

def fetch_sparql(endpoint_url: str, query: str) -> pd.DataFrame:
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    # Get variable names (column names)
    cols = results["head"]["vars"]

    # Build rows
    rows = []
    for result in results["results"]["bindings"]:
        row = {}
        for col in cols:
            if col in result:
                row[col] = result[col]["value"]
            else:
                row[col] = None
        rows.append(row)

    return pd.DataFrame(rows)

endpoint = "https://linkedearth.graphdb.mint.isi.edu/repositories/LiPDVerse-dynamic"
query = """PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX xml: <http://www.w3.org/XML/1998/namespace>
PREFIX dct: <http://purl.org/dc/terms/>
PREFIX le: <http://linked.earth/ontology#>
PREFIX pvar: <http://linked.earth/ontology/paleo_variables#>
PREFIX pproxy: <http://linked.earth/ontology/paleo_proxy#>
PREFIX arch: <http://linked.earth/ontology/archive#>
PREFIX punits: <http://linked.earth/ontology/paleo_units#>

SELECT
  # ?TSiD
  (SAMPLE(?dataSetName) AS ?dataSetName)
  (SAMPLE(?archiveType) AS ?archiveType)
  (SAMPLE(?Latitude) AS ?Latitude)
  (SAMPLE(?Longitude) AS ?Longitude)
  (SAMPLE(?Elevation) AS ?Elevation)
  (SAMPLE(?paleoData_variableName) AS ?paleoData_variableName)
  (SAMPLE(?paleoData_standardName) AS ?paleoData_standardName)
  (SAMPLE(?paleoData_values) AS ?paleoData_values)
  (SAMPLE(?paleoData_units) AS ?paleoData_units)
  (SAMPLE(?paleoData_proxy) AS ?paleoData_proxy)
  (SAMPLE(?paleoData_proxyGeneral) AS ?paleoData_proxyGeneral)
  (SAMPLE(?time_variableName) AS ?time_variableName)
  (SAMPLE(?time_standardName) AS ?time_standardName)
  (SAMPLE(?time_values) AS ?time_values)
  (SAMPLE(?time_units) AS ?time_units)
WHERE {
  # ?dataset a le:Dataset ;
           le:hasName ?dataSetName ;
           le:hasArchiveType ?archiveTypeURI ;
           le:hasLocation ?loc ;
           le:hasPaleoData ?paleoData .
  # ?archiveTypeURI rdfs:label ?archiveType .

  # ?loc a le:Location ;
       le:hasLatitude ?Latitude ;
       le:hasLongitude ?Longitude .
  OPTIONAL { ?loc le:hasElevation ?Elevation . }

  # ?paleoData a le:PaleoData ;
             le:hasMeasurementTable ?table .
  # ?table a le:DataTable .

  # Paleo variable filtered by name (temperature-like), no interpretation constraint
  # ?table le:hasVariable ?paleoVar .
  # ?paleoVar a le:Variable ;
            le:hasName ?paleoData_variableName ;
            le:hasValues ?paleoData_values ;
            le:hasVariableId ?TSiD ;
            le:partOfCompilation ?comp .
  FILTER(regex(?paleoData_variableName, "temp", "i"))

  OPTIONAL {
    # ?paleoVar le:hasStandardVariable ?paleoData_standardNameURI .
    # ?paleoData_standardNameURI rdfs:label ?paleoData_standardName .
  }
  OPTIONAL {
    # ?paleoVar le:hasUnits ?paleoData_unitsURI .
    # ?paleoData_unitsURI rdfs:label ?paleoData_units .
  }
  OPTIONAL {
    # ?paleoVar le:hasProxy ?paleoData_proxyURI .
    # ?paleoData_proxyURI rdfs:label ?paleoData_proxy .
  }
  OPTIONAL {
    # ?paleoVar le:hasProxyGeneral ?paleoData_proxyGeneralURI .
    # ?paleoData_proxyGeneralURI rdfs:label ?paleoData_proxyGeneral .
  }

  # ?comp a le:Compilation ; le:hasName ?compName .
  FILTER(?compName = "Temp12k")

  # Associated time variable must be age (exclude year)
  # ?table le:hasVariable ?timeVar .
  # ?timeVar a le:Variable ;
           le:hasName ?time_variableName ;
           le:hasStandardVariable ?time_standardNameURI ;
           le:hasValues ?time_values ;
           le:hasUnits ?time_unitsURI .
  FILTER(?time_standardNameURI = pvar:age)
  # ?time_standardNameURI rdfs:label ?time_standardName .
  # ?time_unitsURI rdfs:label ?time_units .
}
GROUP BY ?TSiD"""
df_data = fetch_sparql(endpoint, query)
display(df_data.head())
# Out:
#            TSiD                 dataSetName    archiveType  Latitude  \
# 0   RTdDwazy1bI  MilandreCave.Affolter.2019     Speleothem     47.49
# 1  M2Lx32u25tbP           Hams.Bennett.1987  Lake sediment     43.24
# 2  M2L8sc7gn3mP           Hams.Bennett.1987  Lake sediment     43.24
# 3  M2L7thzxje2P           Hams.Bennett.1987  Lake sediment     43.24
# 4   R3Ypu5QP5eP         EagleTarn.Rees.2010  Lake sediment  -42.6799
#
#   Longitude Elevation paleoData_variableName paleoData_standardName  \
# 0      7.02     491.0            temperature            temperature
# 1    -80.41     301.0            temperature            temperature
# 2    -80.41     301.0            temperature            temperature
# 3    -80.41     301.0            temperature            temperature
# 4  146.5914    1040.0            temperature            temperature
#
#                                     paleoData_values paleoData_units  \
# 0  [8.3, 8.9, 7.7, 7.9, 8.1, 8.5, 8.1, 7.4, 7.4, ...            degC
# 1  [-6.271, -6.529, -6.229, -6.457, -5.8, -5.443,...            degC
# 2  [21.229, 20.986, 21.586, 20.957, 21.729, 21.88...            degC
# 3  [8.015, 7.7, 8.31, 7.798, 8.595, 8.849, 8.5, 8...            degC
# 4  [9.867, 9.369, 10.489, 8.589, 7.429, 7.704, 7....            degC
#
#   paleoData_proxy paleoData_proxyGeneral time_variableName time_standardName  \
# 0              dD               isotopic               age               age
# 1          pollen                    NaN               age               age
# 2          pollen                    NaN               age               age
# 3          pollen                    NaN               age               age
# 4      chironomid                    NaN               age               age
#
#                                          time_values time_units
# 0  [-19.5, 131.5, 138.5, 146.0, 151.0, 157.0, 164...      yr BP
# 1  [-29, 24, 80, 136, 315, 512, 625, 753, 882, 10...  yr 14C BP
# 2  [-29, 24, 80, 136, 315, 512, 625, 753, 882, 10...  yr 14C BP
# 3  [-29, 24, 80, 136, 315, 512, 625, 753, 882, 10...  yr 14C BP
# 4  [29.809, 59.618, 357.708, 417.326, 506.753, 59...      yr BP

# %% [markdown]
# Some of the value arrays were not properly JSON encoded, so we need to create a parser to handle these use cases:

# %%
import json

def safe_json_loads(row):
    if not isinstance(row, str):
        return row

    try:
        # Fast path: normal JSON
        return json.loads(row)
    except json.JSONDecodeError:
        # Slow path: fix escaped quotes
        try:
            fixed = row.replace(r'\"', '"').strip()
            return json.loads(fixed)
        except Exception:
            # Absolute fallback: mark as NaN so it doesn't break pipelines
            return np.nan

# %%
df = df_data.copy()

df['paleoData_values'] = df['paleoData_values'].apply(safe_json_loads)
df['time_values'] = df['time_values'].apply(safe_json_loads)

# %%
import numpy as np
import pandas as pd

def coerce_list_to_float_nan(v):
    if not isinstance(v, list):
        return v

    out = []
    for x in v:
        if x is None:
            out.append(np.nan)
        else:
            try:
                out.append(float(x))
            except Exception:
                out.append(np.nan)
    return out

# %%
df['paleoData_values'] = df['paleoData_values'].apply(coerce_list_to_float_nan)
df['time_values']      = df['time_values'].apply(coerce_list_to_float_nan)

# %% [markdown]
# ### Importing into Pyleoclim

# %% [markdown]
# Let's import the data into a [`MultipleGeoseries` object](https://pyleoclim-util.readthedocs.io/en/latest/core/api.html#pyleoclim.core.multiplegeoseries.MultipleGeoSeries) for mapping purposes:

# %%
import pyleoclim as pyleo

ts_list = []

for _, row in df.iterrows():
    if row['time_values'] is not None and row['paleoData_values'] is not None: #there seems to be missing entries in the database (added by DK)
        if np.all(np.isnan(row['time_values'])) == False and np.all(np.isnan(row['paleoData_values'])) == False: #check that not all the values are false (added by DK)
            ts_list.append(pyleo.GeoSeries(time=row['time_values'],value=row['paleoData_values'],
                                   time_name=row['time_variableName'],value_name=row['paleoData_variableName'],
                                   time_unit=row['time_units'], value_unit=row['paleoData_units'],
                                   lat = row['Latitude'], lon = row['Longitude'],
                                   elevation = row['Elevation'], observationType = row['paleoData_proxy'],
                                   archiveType = row['archiveType'], verbose = False, 
                                   label=row['dataSetName']+'_'+row['TSiD'])) 

temp12k = pyleo.MultipleGeoSeries(ts_list, label='Temp12k', time_unit='yr BP')

# %% [markdown]
# Let's map the records:

# %%
fig,ax = temp12k.map(projection='Robinson', figsize=[12, 6], hue='archiveType', scatter_kwargs={'s': 50})

# %% [markdown]
# ## Spectral Analysis
#
# In order to identify period peaks in the various records, we will run spectral analysis. For speed, we will use the MTM method. The workflows will be as follows:
# 1. Slice the timeseries between 0-10,000 years
# 2. Ensure that the resolution is at least 300 years over this period; if not, skip
# 3. Cover at least 7,000 years in the Holocene; if not, skip
# 4. Interpolate using linear interpolation (the interpolation step is the mean spacing between consecutive points)
# 5. Detrend using Empirical Mode Decomposition
# 6. Standardize
# 7. Run spectral analysis using MTM method
# 8. Estimate significance
#
# Since we are interested in each GeoSeries individually, we will apply the analysis on individual records instead of the MultipleGeoSeries object:

# %%
psd_list = []

for idx, item in enumerate(ts_list):
    ts_slice = item.slice([0,10000])
    if ts_slice.resolution().describe()['mean'] < 300 and np.max(ts_slice.time)-np.min(ts_slice.time)>7000:
        psd_list.append(ts_slice.interp().detrend().standardize().spectral(method='mtm').signif_test(number=1000)) 
    else:      
        pass
# Out:
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 377.41it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 411.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.50it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.57it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.17it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.83it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.64it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 356.60it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.75it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 370.63it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.54it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 373.53it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.91it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.28it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.98it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.91it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.94it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 408.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.27it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 375.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.55it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.58it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.32it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 411.43it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.11it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 376.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 369.18it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 362.81it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 333.63it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 319.27it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 374.90it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 366.99it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 373.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 379.08it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.24it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.14it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.36it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.91it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 379.46it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.22it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 369.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.75it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.29it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.98it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.71it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.38it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.71it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.28it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.95it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.08it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.19it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.35it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.82it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.74it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 383.45it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.66it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.30it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 383.48it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.12it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 382.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.12it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 372.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.14it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 374.31it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 347.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 372.32it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 380.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 377.94it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.04it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.81it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.26it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.29it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.44it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.11it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.74it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.31it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.41it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.10it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.45it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 383.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.72it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.91it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 369.52it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 361.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 371.45it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 380.40it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 367.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 380.48it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.92it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.33it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.48it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.37it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.62it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:04<00:00, 222.30it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.99it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 368.71it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 334.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 342.12it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 347.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 360.92it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 363.04it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 366.20it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 355.82it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 372.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 376.40it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 380.15it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 372.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.73it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.31it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 328.36it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 313.75it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 367.55it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 355.17it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 356.73it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 354.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 367.86it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 365.83it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 361.96it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 352.33it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 356.91it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 373.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 374.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 374.10it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 367.41it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 362.89it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 365.52it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 360.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 302.43it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 305.74it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 301.53it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 352.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 364.20it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 361.00it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 350.58it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 366.19it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 369.27it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 361.15it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 365.64it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.85it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.01it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.01it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 345.72it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 366.75it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 346.96it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 356.60it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 354.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 352.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 354.53it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 348.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 363.01it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 362.40it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 364.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 358.16it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 345.15it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 368.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 368.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 349.63it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 353.47it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 376.23it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 372.22it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 367.75it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 370.33it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 353.39it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 382.90it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.81it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.38it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.36it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.83it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.28it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.62it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 383.88it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.68it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 380.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.60it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.21it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.11it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.57it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.91it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 366.49it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.16it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.35it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 410.08it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.54it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 374.10it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.63it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.72it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.56it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 409.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 409.34it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.28it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.64it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.04it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.18it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 377.05it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.68it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.34it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.29it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.88it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.65it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.39it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 369.93it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.00it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.75it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.00it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.91it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 408.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.23it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.09it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.82it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.38it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.37it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.14it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.92it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.84it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.21it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.16it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.08it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.28it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.14it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.01it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.47it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.56it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 368.50it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 382.86it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.94it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.14it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.04it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.94it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 374.99it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 369.92it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.94it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.31it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 372.38it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 370.65it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.93it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.48it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.62it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.85it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 362.33it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.00it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.48it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.81it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.44it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.34it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.50it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.52it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.43it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.43it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.11it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.81it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.07it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.75it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.30it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.11it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.49it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.86it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.71it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.50it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.47it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.55it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.52it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.23it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.45it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.34it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.15it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.17it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 329.92it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 370.74it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.64it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.95it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.80it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.98it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.33it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.83it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.44it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.83it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.30it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.07it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.92it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.52it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.89it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 383.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 346.26it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 371.22it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.43it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 371.72it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 374.99it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.93it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.88it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.80it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.54it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.12it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.91it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.24it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.49it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.90it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.73it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.49it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.73it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.66it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.24it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.26it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.46it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.26it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 372.56it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 377.93it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.93it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.30it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 334.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.19it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 382.15it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 353.74it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.65it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 367.38it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.20it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.37it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.92it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.24it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 380.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.47it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 375.18it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.47it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.98it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.39it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.24it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 373.90it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.40it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.65it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.58it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.39it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.07it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.18it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 409.16it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.56it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.96it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 410.53it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 408.10it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.88it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.70it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.82it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 408.05it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.18it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.90it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 408.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.55it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.55it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.00it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.43it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.12it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.23it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.49it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 377.92it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.66it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 370.64it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.14it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.60it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.76it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.36it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.52it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.27it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.37it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.29it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.99it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 365.80it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.82it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.70it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.70it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 388.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.27it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 373.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.95it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 387.31it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 371.22it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 368.72it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 347.33it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 378.48it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 315.53it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 366.30it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 355.88it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 377.26it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.85it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 381.17it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.89it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.39it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 380.18it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 386.43it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 371.39it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 376.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 379.46it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.15it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 368.03it/s]
# ...
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.15it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.28it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.90it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.40it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.16it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.76it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.60it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.63it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.83it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.88it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.41it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.84it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.35it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.18it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.64it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 410.84it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.94it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.12it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.93it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.21it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.15it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.47it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.95it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.01it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.85it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.37it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.46it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 408.50it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.47it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.44it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.24it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.48it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.14it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.99it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 409.46it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.50it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.62it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.99it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.45it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.79it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 406.31it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:05<00:00, 172.00it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.82it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.74it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.19it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.18it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 358.25it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.01it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.87it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 384.84it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 389.45it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.98it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.37it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.09it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 363.69it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 370.44it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.51it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 371.57it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.28it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 396.55it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.54it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.80it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 393.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.35it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.99it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.81it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 382.04it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.26it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 365.82it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 357.54it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 385.49it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.55it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.93it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.56it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.28it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.47it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 376.71it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 379.42it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 391.90it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.57it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.74it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.55it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:04<00:00, 238.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.86it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.94it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.23it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 408.07it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 409.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.23it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 407.74it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.98it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 405.54it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.80it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 383.22it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.11it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 404.02it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.52it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:03<00:00, 258.27it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.73it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 408.24it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.03it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 382.05it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.35it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.70it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.04it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.90it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.06it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 371.34it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.67it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 375.00it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.61it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.95it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 392.89it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.97it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.62it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.53it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.76it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 380.17it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.31it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.58it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 395.39it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.41it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 398.53it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 397.37it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.81it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 401.78it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 399.95it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 402.93it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 394.77it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 400.36it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 403.13it/s]
# Performing spectral analysis on individual series: 100%|██████████| 1000/1000 [00:02<00:00, 390.10it/s]

# %%
print(f"This leaves us with {len(psd_list)} records")
# Out:
# This leaves us with 826 records

# %% [markdown]
# Let's reorganize the data into a DataFrame to make it easier to analyze and plot the results.

# %%
label = []
lat = []
lon = []
archive = []
amp =[]
period = []
unit = []
signif = []

for item in psd_list:
    label.append(item.timeseries.label)
    lat.append(item.timeseries.lat)
    lon.append(item.timeseries.lon)
    archive.append(item.timeseries.archiveType)
    amp.append(item.amplitude)
    period.append(1/item.frequency)
    unit.append(item.period_unit)
    signif.append(item.signif_qs.psd_list[0].amplitude)

# Put it in a DataFrame
df_psd = pd.DataFrame({'Name':label,
                       'Latitude':lat,
                       'Longitude':lon,
                       'Archive':archive,
                       'Amplitude':amp,
                       'Period':period,
                       'Units':unit,
                       'AR1': signif})

display(df_psd.head())
# Out:
#                                      Name  Latitude  Longitude        Archive  \
# 0  MilandreCave.Affolter.2019_RTdDwazy1bI   47.4900     7.0200     Speleothem
# 1          Hams.Bennett.1987_M2Lx32u25tbP   43.2400   -80.4100  Lake sediment
# 2          Hams.Bennett.1987_M2L8sc7gn3mP   43.2400   -80.4100  Lake sediment
# 3          Hams.Bennett.1987_M2L7thzxje2P   43.2400   -80.4100  Lake sediment
# 4         EagleTarn.Rees.2010_R3Ypu5QP5eP  -42.6799   146.5914  Lake sediment
#
#                                            Amplitude  \
# 0  [nan, 297.86273293454246, 491.1713902734278, 5...
# 1  [nan, 446.3995208636168, 475.273075214222, 370...
# 2  [nan, 807.4810157740312, 971.2050077843061, 97...
# 3  [nan, 1054.455514080586, 1193.3324093048109, 1...
# 4  [nan, 590.4217629024698, 573.882011815157, 667...
#
#                                               Period Units  \
# 0  [inf, 9842.499999999967, 4921.249999999984, 32...    yr
# 1  [inf, 9947.999999999998, 4973.999999999999, 33...    yr
# 2  [inf, 9947.999999999998, 4973.999999999999, 33...    yr
# 3  [inf, 9947.999999999998, 4973.999999999999, 33...    yr
# 4  [inf, 9924.615000000003, 4962.307500000002, 33...    yr
#
#                                                  AR1
# 0  [nan, 543.369806611196, 497.63453989646155, 45...
# 1  [nan, 811.9330864859046, 742.3338712400134, 67...
# 2  [nan, 1662.559326016816, 1537.6821643508076, 1...
# 3  [nan, 1946.2339858928917, 1779.5207794993667, ...
# 4  [nan, 1742.5716221323119, 1570.6637671238936, ...

# %% [markdown]
# Since this takes quite a bit of time to run, let's pickle the file:

# %%
import pickle

with open("../data/temp12k_peaks.pkl", "wb") as f:   # 'wb' = write binary
    pickle.dump(df_psd, f)

# %%
with open("../data/temp12k_psd.pkl", "wb") as f:   # 'wb' = write binary
    pickle.dump(psd_list, f)

# %% [markdown]
# ## Chasing cyclicities over the Holocene.
#
# First, let's have a look at some of the spectra generated in the previous step. We will regenerate 12 random periodograms.

# %%
import pickle

with open("../data/temp12k_peaks.pkl", "rb") as f:   # 'rb' = read binary
    df_psd = pickle.load(f)

with open("../data/temp12k_psd.pkl", "rb") as f:   # 'wb' = read binary
    psd_list = pickle.load(f)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyleoclim as pyleo

rng = np.random.default_rng(42) #set a seed for reproducibility. 42 is the answer to everything
random_values = rng.permutation(len(df_psd))[0:9]

# Create the figure and set of subplots
fig,ax = plt.subplots(3,3, figsize = (12,12))

k = 0
for i in range(3):
    for j in range(3):
        val = random_values[k]
        psd = psd_list[val]

        # deal with the title
        lbl = psd.timeseries.label.split('_')[0]

        psd.plot(
            title=lbl,
            ax=ax[i, j],
            legend = False
        )
        k += 1

# %% [markdown]
# Some records display millennial-scale periodicities over the Holocene but very few are significant above red noise (defined here at 95% threshold).
#
# Let's have a closer look at the number of records with significant peaks corresponding to periodicities in the 800-3000 year range.

# %%
import numpy as np
import pandas as pd

def find_red_noise_peaks(period, amplitude, ar1,
                         pmin=800, pmax=3000):
    """
    Return indices of peaks above red noise
    within a given period band.
    """
    period = np.asarray(period, dtype=float)
    amplitude = np.asarray(amplitude, dtype=float)
    ar1 = np.asarray(ar1, dtype=float)

    # Mask invalid values
    valid = (
        np.isfinite(period) &
        np.isfinite(amplitude) &
        np.isfinite(ar1)
    )

    period = period[valid]
    amplitude = amplitude[valid]
    ar1 = ar1[valid]

    # Period band
    band = (period >= pmin) & (period <= pmax)

    # Above red noise
    significant = amplitude > ar1

    mask = band & significant

    return period[mask], amplitude[mask], ar1[mask]

# %%
df_peaks = df_psd.copy()

df_peaks[["sig_periods", "sig_amplitudes", "sig_ar1"]] = (
    df_peaks.apply(
        lambda row: pd.Series(
            find_red_noise_peaks(
                row["Period"],
                row["Amplitude"],
                row["AR1"]
            )
        ),
        axis=1
    )
)

display(df_peaks.head())
# Out:
#                                      Name  Latitude  Longitude        Archive  \
# 0  MilandreCave.Affolter.2019_RTdDwazy1bI   47.4900     7.0200     Speleothem
# 1          Hams.Bennett.1987_M2Lx32u25tbP   43.2400   -80.4100  Lake sediment
# 2          Hams.Bennett.1987_M2L8sc7gn3mP   43.2400   -80.4100  Lake sediment
# 3          Hams.Bennett.1987_M2L7thzxje2P   43.2400   -80.4100  Lake sediment
# 4         EagleTarn.Rees.2010_R3Ypu5QP5eP  -42.6799   146.5914  Lake sediment
#
#                                            Amplitude  \
# 0  [nan, 297.86273293454246, 491.1713902734278, 5...
# 1  [nan, 446.3995208636168, 475.273075214222, 370...
# 2  [nan, 807.4810157740312, 971.2050077843061, 97...
# 3  [nan, 1054.455514080586, 1193.3324093048109, 1...
# 4  [nan, 590.4217629024698, 573.882011815157, 667...
#
#                                               Period Units  \
# 0  [inf, 9842.499999999967, 4921.249999999984, 32...    yr
# 1  [inf, 9947.999999999998, 4973.999999999999, 33...    yr
# 2  [inf, 9947.999999999998, 4973.999999999999, 33...    yr
# 3  [inf, 9947.999999999998, 4973.999999999999, 33...    yr
# 4  [inf, 9924.615000000003, 4962.307500000002, 33...    yr
#
#                                                  AR1  \
# 0  [nan, 543.369806611196, 497.63453989646155, 45...
# 1  [nan, 811.9330864859046, 742.3338712400134, 67...
# 2  [nan, 1662.559326016816, 1537.6821643508076, 1...
# 3  [nan, 1946.2339858928917, 1779.5207794993667, ...
# 4  [nan, 1742.5716221323119, 1570.6637671238936, ...
#
#                                          sig_periods  \
# 0  [2460.624999999992, 1968.4999999999934, 1640.4...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                       sig_amplitudes  \
# 0  [549.1074872980157, 569.837630158562, 565.6923...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                              sig_ar1
# 0  [489.6167837753966, 485.9757547067824, 484.990...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []

# %% [markdown]
# Let's flatten the DataFrame to one row per peak:

# %%
rows = []

for _, row in df_peaks.iterrows():
    for p, a, r in zip(row["sig_periods"],
                       row["sig_amplitudes"],
                       row["sig_ar1"]):
        rows.append({
            "Latitude": row["Latitude"],
            "Longitude": row["Longitude"],
            "Archive": row["Archive"],
            "Period": p,
            "Amplitude": a,
            "AR1": r
        })

df_peaks_flat = pd.DataFrame(rows)

# %% [markdown]
# Let's derive some statistical information:

# %%
df_peaks_flat["Period"].describe()
# Out:
# count     456.000000
# mean     1485.553985
# std       554.376845
# min       809.515794
# 25%      1059.575104
# 50%      1342.732369
# 75%      1774.350608
# max      2997.081231
# Name: Period, dtype: float64

# %% [markdown]
# ### Global view of significant millennial periodicities.
#
# Let's create a simple histograms of the identified peaks:

# %%
import numpy as np

mask = (
    np.isfinite(df_peaks_flat["Period"]) &
    (df_peaks_flat["Period"] >= 800) &
    (df_peaks_flat["Period"] <= 3000)
)

df_peaks_flat = df_peaks_flat.loc[mask].copy() #make sure that nothing weird happened during flattening

import matplotlib.pyplot as plt

bins = np.arange(800, 3000 + 100, 100)

plt.figure(figsize=(8, 4))
plt.hist(df_peaks_flat["Period"], bins=bins)
plt.xlabel("Period (years)")
plt.ylabel("Number of significant peaks")
plt.title("Density of significant periodicities (800–3000 yr)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Also let's see if some sites contribute more information than others:

# %%
df_peaks_flat.groupby(["Latitude", "Longitude"]).size().describe()
# Out:
# count    155.000000
# mean       2.941935
# std        2.626634
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max       17.000000
# dtype: float64

# %% [markdown]
# On average, each site has 2-3 peaks in the millennial band. Let's map the number of peaks for each record:

# %%
import pandas as pd

df_peak_counts = (
    df_peaks_flat
    .groupby(["Latitude", "Longitude", "Archive"])
    .size()
    .reset_index(name="n_peaks")
)

# %%
df_peak_counts['Archive'].unique()
# Out:
# <StringArray>
# [    'Glacier ice', 'Marine sediment',          'Midden',            'Peat',
#    'Lake sediment',      'Speleothem',            'Wood']
# Length: 7, dtype: str

# %%
archive_markers = {
    "Glacier ice": "^",        
    "Marine sediment": "s",          
    "Midden": "v",    
    "Peat": "<",           
    "Lake sediment": "D",
    "Speleothem": '*',
    "Wood" : 'o'}

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

fig = plt.figure(figsize=(11, 5))
ax = plt.axes(projection=ccrs.Robinson())

ax.set_global()
ax.coastlines(linewidth=0.8)
ax.add_feature(cfeature.BORDERS, linewidth=0.3)
ax.add_feature(cfeature.LAND, facecolor="lightgray")
ax.add_feature(cfeature.OCEAN, facecolor="white")

for archive, marker in archive_markers.items():
    subset = df_peak_counts[df_peak_counts["Archive"] == archive]

    if subset.empty:
        continue

    sc = ax.scatter(
        subset["Longitude"],
        subset["Latitude"],
        c=subset["n_peaks"],
        s=50,
        #s = 20 + 10 * subset["n_peaks"],
        cmap="viridis",
        marker=marker,
        transform=ccrs.PlateCarree(),
        edgecolor="k",
        linewidth=0.3,
        label=archive
    )

# Colorbar (shared)
cbar = plt.colorbar(sc, ax=ax, orientation="horizontal", pad=0.05)
cbar.set_label("Number of significant peaks per record (800–3000 yr)")

# Legend for archive types
ax.legend(
    title="Archive",
    bbox_to_anchor=(1.3, 1),
    loc="upper right",
    frameon=True
)

plt.title("Spatial distribution of significant millennial-scale periodicities\n(symbol = archive type)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Periodicities by latitude and archive

# %%
import numpy as np
import pandas as pd

df_lp = df_peaks_flat.copy()

mask = (
    np.isfinite(df_lp["Period"]) &
    np.isfinite(df_lp["Latitude"]) &
    (df_lp["Period"] >= 800) &
    (df_lp["Period"] <= 3000)
)

df_lp = df_lp.loc[mask].copy()

# %%
import matplotlib.pyplot as plt
import numpy as np

archives = sorted(df_lp["Archive"].dropna().unique())
n = len(archives)

ncols = 3 if n >= 3 else n
nrows = int(np.ceil(n / ncols))

fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(4.5 * ncols, 3.5 * nrows),
    sharex=True,
    sharey=True
)

axes = np.atleast_1d(axes).ravel()

for ax, arch in zip(axes, archives):
    sub = df_lp[df_lp["Archive"] == arch]

    ax.scatter(
        sub["Period"],
        sub["Latitude"],
        s=15,
        alpha=0.6
    )

    ax.set_title(f"{arch} (n={len(sub)})")
    ax.grid(True, linewidth=0.3)

# Turn off unused panels
for ax in axes[len(archives):]:
    ax.axis("off")

for ax in axes[:len(archives)]:
    ax.set_xlim(800, 3000)
    ax.set_xlabel("Period (years)")
    ax.set_ylabel("Latitude")

fig.suptitle(
    "Latitude vs Period for all significant peaks (800–3000 yr), by archive",
    y=1.02
)

plt.tight_layout()
plt.show()

# %% [markdown]
# Let's redo this figure but use color to indicate how far each peak rises above the AR(1) threshold:

# %%
import numpy as np

df_lp = df_peaks_flat.copy()

mask = (
    np.isfinite(df_lp["Period"]) &
    np.isfinite(df_lp["Latitude"]) &
    np.isfinite(df_lp["Amplitude"]) &
    np.isfinite(df_lp["AR1"]) &
    (df_lp["Period"] >= 800) & (df_lp["Period"] <= 3000) &
    (df_lp["AR1"] > 0)
)

df_lp = df_lp.loc[mask].copy()
df_lp["strength"] = df_lp["Amplitude"] / df_lp["AR1"]

df_lp = df_lp[np.isfinite(df_lp["strength"])].copy()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec

archives = sorted(df_lp["Archive"].dropna().unique())
n = len(archives)

ncols = 3
nrows = int(np.ceil(n / ncols))

fig = plt.figure(figsize=(4.8 * ncols, 3.6 * nrows + 1.0))
gs = GridSpec(nrows + 1, ncols, height_ratios=[1]*nrows + [0.08], hspace=0.35)

axes = []
for i in range(nrows):
    for j in range(ncols):
        axes.append(fig.add_subplot(gs[i, j]))

# Robust linear color limits
vmin, vmax = np.nanpercentile(df_lp["strength"], [2, 98])

mappable = None
for ax, arch in zip(axes, archives):
    sub = df_lp[df_lp["Archive"] == arch]

    mappable = ax.scatter(
        sub["Period"],
        sub["Latitude"],
        c=sub["strength"],
        s=15,
        alpha=0.7,
        vmin=vmin,
        vmax=vmax
    )

    ax.set_title(f"{arch} (n={len(sub)})")
    ax.grid(True, linewidth=0.3)
    ax.set_xlim(800, 3000)
    ax.set_xlabel("Period (years)")
    ax.set_ylabel("Latitude")

# Turn off unused axes
for ax in axes[len(archives):]:
    ax.axis("off")

# Colorbar axis spanning all columns
cax = fig.add_subplot(gs[-1, :])
cbar = fig.colorbar(mappable, cax=cax, orientation="horizontal")
cbar.set_label("Amplitude / AR1 (strength above red-noise background)")

fig.suptitle(
    "Latitude vs Period for all significant peaks (800–3000 yr)\nColored by peak strength (Amplitude / AR(1))",
    y=0.98
)

plt.show()

# %% [markdown]
# We see that there is no significant clustering of peaks across latitude/archives.
#
# ### Conclusion
# In conclusion, Temperature 12k records exhibit a number of spectral peaks in the 800-3000y range, without clear link to geography or archive type. This result would need to be confirmed by using an interpolation-free spectral method like the Weighted-Wavelet Z-transform, though this would considerably increase the computational requirement.  Note that we did not assess the effect of age uncertainties, which likely contrinute to the spread of peaks over the 800-3000y range.  What does this mean for the "solar hypothesis"? The presence of spectral peaks in climate records at periods similar to those of the solar forcing is not a sufficient condition to establish a solar driver; for a more rigorous analysis, the reader is referred to [Landers et al. (2025)](https://doi.org/10.22541/essoar.176598901.17168843/v1). However, since such frequency-domain investigations remain common in paleolcimatology, we believe it is useful to show how they can be carried out in the Python LinkedEarth research ecosystem.
